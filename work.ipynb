# %%
# !pip install dgl-cu113 dglgo -f https://data.dgl.ai/wheels/repo.html
# !pip install pysmiles
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.dgl.ai/wheels/repo.html
# ...
#      |████████████████████████████████| 220.6 MB 44 kB/s
# ...
#      |████████████████████████████████| 77 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 281 kB 36.7 MB/s
# ...
#      |████████████████████████████████| 51 kB 797 kB/s
# ...
#      |████████████████████████████████| 103 kB 73.5 MB/s
# ...
#      |████████████████████████████████| 109 kB 73.4 MB/s
# ...
#      |████████████████████████████████| 45 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 11.1 MB 60.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 59.1 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 67.7 MB/s
# ...
#      |████████████████████████████████| 546 kB 32.8 MB/s
# ...
#      |████████████████████████████████| 84 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 100 kB 11.7 MB/s
# ...

# %%
import os
import torch

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('drive/MyDrive/MolR')

# %%
os.chdir('data/USPTO-479k')

# %%
#!unzip USPTO-479k.zip

# %%
os.chdir('../../src/')

# %% [markdown]
# # Reproduction

# %%
#Normal Run TAG
# !python main.py
# Out:
# DGL backend not selected or invalid.  Assuming PyTorch for now.
# Setting the default backend to "pytorch". You can change it in the ~/.dgl/config.json file or export the DGLBACKEND environment variable.  Valid options are: pytorch, mxnet, tensorflow (all lowercase)
#
# ...
# gpu: 0
# task: pretrain
# dataset: USPTO-479k
# epoch: 20
# batch_size: 4096
# gnn: tag
# layer: 2
# dim: 1024
# margin: 4.0
# lr: 0.0001
# save_model: False
# ...
#
# current working directory: /content/drive/MyDrive/MolR/src
#
# cache found
# loading feature encoder from ../data/USPTO-479k/cache/feature_encoder.pkl
# loading train reactants from ../data/USPTO-479k/cache/train_reactant_graphs.bin
# loading train products from ../data/USPTO-479k/cache/train_product_graphs.bin
# moving train data to GPU
# loading valid reactants from ../data/USPTO-479k/cache/valid_reactant_graphs.bin
# loading valid products from ../data/USPTO-479k/cache/valid_product_graphs.bin
# moving valid data to GPU
# ...

# %%
#Normal Run GCN
# !python main.py --gnn gcn
# Out:
# DGL backend not selected or invalid.  Assuming PyTorch for now.
# Setting the default backend to "pytorch". You can change it in the ~/.dgl/config.json file or export the DGLBACKEND environment variable.  Valid options are: pytorch, mxnet, tensorflow (all lowercase)
#
# ...
# gpu: 0
# task: pretrain
# dataset: USPTO-479k
# epoch: 20
# batch_size: 4096
# gnn: gcn
# layer: 2
# dim: 1024
# margin: 4.0
# lr: 0.0001
# save_model: False
# ...
#
# current working directory: /content/drive/MyDrive/MolR/src
#
# cache found
# loading feature encoder from ../data/USPTO-479k/cache/feature_encoder.pkl
# loading train reactants from ../data/USPTO-479k/cache/train_reactant_graphs.bin
# loading train products from ../data/USPTO-479k/cache/train_product_graphs.bin
# moving train data to GPU
# loading valid reactants from ../data/USPTO-479k/cache/valid_reactant_graphs.bin
# loading valid products from ../data/USPTO-479k/cache/valid_product_graphs.bin
# moving valid data to GPU
# ...

# %%
#Normal Run GAT
# !python main.py --gnn gat
# Out:
# ...
# gpu: 0
# task: pretrain
# dataset: USPTO-479k
# epoch: 20
# batch_size: 4096
# gnn: gat
# layer: 2
# dim: 1024
# margin: 4.0
# lr: 0.0001
# save_model: False
# ...
#
# current working directory: /content/drive/MyDrive/MolR/src
#
# cache found
# loading feature encoder from ../data/USPTO-479k/cache/feature_encoder.pkl
# loading train reactants from ../data/USPTO-479k/cache/train_reactant_graphs.bin
# loading train products from ../data/USPTO-479k/cache/train_product_graphs.bin
# moving train data to GPU
# loading valid reactants from ../data/USPTO-479k/cache/valid_reactant_graphs.bin
# loading valid products from ../data/USPTO-479k/cache/valid_product_graphs.bin
# moving valid data to GPU
# loading test reactants from ../data/USPTO-479k/cache/test_reactant_graphs.bin
# loading test products from ../data/USPTO-479k/cache/test_product_graphs.bin
# moving test data to GPU
# start training
#
# initial case:
# valid  mrr: 0.4439  mr: 1448.6451  h1: 0.3756  h3: 0.4865  h5: 0.5222  h10: 0.5619
# ...

# %%
#Normal Run SAGE
# !python main.py --gnn sage
# Out:
# ...
# gpu: 0
# task: pretrain
# dataset: USPTO-479k
# epoch: 20
# batch_size: 4096
# gnn: sage
# layer: 2
# dim: 1024
# margin: 4.0
# lr: 0.0001
# save_model: False
# ...
#
# current working directory: /content/drive/MyDrive/MolR/src
#
# cache found
# loading feature encoder from ../data/USPTO-479k/cache/feature_encoder.pkl
# loading train reactants from ../data/USPTO-479k/cache/train_reactant_graphs.bin
# loading train products from ../data/USPTO-479k/cache/train_product_graphs.bin
# moving train data to GPU
# loading valid reactants from ../data/USPTO-479k/cache/valid_reactant_graphs.bin
# loading valid products from ../data/USPTO-479k/cache/valid_product_graphs.bin
# moving valid data to GPU
# loading test reactants from ../data/USPTO-479k/cache/test_reactant_graphs.bin
# loading test products from ../data/USPTO-479k/cache/test_product_graphs.bin
# moving test data to GPU
# start training
#
# initial case:
# valid  mrr: 0.5419  mr: 1491.7592  h1: 0.4986  h3: 0.5686  h5: 0.5899  h10: 0.6145
# ...

# %% [markdown]
# # Experiment

# %% [markdown]
# Experimented with basic things such as changed pooling layers and hyperparameters. Changing the margin gave slightly better results.

# %%
#Normal Run TAG
# !python main.py --margin 5.0
# Out:
# ...
# gpu: 0
# task: pretrain
# dataset: USPTO-479k
# epoch: 20
# batch_size: 4096
# gnn: tag
# layer: 2
# dim: 1024
# margin: 5.0
# lr: 0.0001
# save_model: False
# ...
#
# current working directory: /content/drive/MyDrive/MolR/src
#
# cache found
# loading feature encoder from ../data/USPTO-479k/cache/feature_encoder.pkl
# loading train reactants from ../data/USPTO-479k/cache/train_reactant_graphs.bin
# loading train products from ../data/USPTO-479k/cache/train_product_graphs.bin
# moving train data to GPU
# loading valid reactants from ../data/USPTO-479k/cache/valid_reactant_graphs.bin
# loading valid products from ../data/USPTO-479k/cache/valid_product_graphs.bin
# moving valid data to GPU
# loading test reactants from ../data/USPTO-479k/cache/test_reactant_graphs.bin
# loading test products from ../data/USPTO-479k/cache/test_product_graphs.bin
# moving test data to GPU
# start training
#
# initial case:
# valid  mrr: 0.4282  mr: 1407.7619  h1: 0.3567  h3: 0.4719  h5: 0.5115  h10: 0.5551
# ...

# %%
#Normal Run TAG
# !python main.py --margin 6.0
# Out:
# ...
# gpu: 0
# task: pretrain
# dataset: USPTO-479k
# epoch: 20
# batch_size: 4096
# gnn: tag
# layer: 2
# dim: 1024
# margin: 6.0
# lr: 0.0001
# save_model: False
# ...
#
# current working directory: /content/drive/MyDrive/MolR/src
#
# cache found
# loading feature encoder from ../data/USPTO-479k/cache/feature_encoder.pkl
# loading train reactants from ../data/USPTO-479k/cache/train_reactant_graphs.bin
# loading train products from ../data/USPTO-479k/cache/train_product_graphs.bin
# moving train data to GPU
# loading valid reactants from ../data/USPTO-479k/cache/valid_reactant_graphs.bin
# loading valid products from ../data/USPTO-479k/cache/valid_product_graphs.bin
# moving valid data to GPU
# loading test reactants from ../data/USPTO-479k/cache/test_reactant_graphs.bin
# loading test products from ../data/USPTO-479k/cache/test_product_graphs.bin
# moving test data to GPU
# start training
#
# initial case:
# valid  mrr: 0.4387  mr: 1391.9045  h1: 0.3709  h3: 0.4803  h5: 0.5155  h10: 0.5570
# ...
